# %%
import pandas as pd

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')

# %%
df.head()
# Out:
#    Year   Lag1   Lag2   Lag3   Lag4   Lag5  Volume  Today Direction
# 0  2001  0.381 -0.192 -2.624 -1.055  5.010  1.1913  0.959        Up
# 1  2001  0.959  0.381 -0.192 -2.624 -1.055  1.2965  1.032        Up
# 2  2001  1.032  0.959  0.381 -0.192 -2.624  1.4112 -0.623      Down
# 3  2001 -0.623  1.032  0.959  0.381 -0.192  1.2760  0.614        Up
# 4  2001  0.614 -0.623  1.032  0.959  0.381  1.2057  0.213        Up

# %%
df.dtypes
# Out:
# Year           int64
# Lag1         float64
# Lag2         float64
# Lag3         float64
# Lag4         float64
# Lag5         float64
# Volume       float64
# Today        float64
# Direction     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       1250 non-null   int64
#  1   Lag1       1250 non-null   float64
#  2   Lag2       1250 non-null   float64
#  3   Lag3       1250 non-null   float64
#  4   Lag4       1250 non-null   float64
#  5   Lag5       1250 non-null   float64
#  6   Volume     1250 non-null   float64
#  7   Today      1250 non-null   float64
#  8   Direction  1250 non-null   object
# dtypes: float64(7), int64(1), object(1)
# memory usage: 88.0+ KB

# %%
df.isnull().sum()
# Out:
# Year         0
# Lag1         0
# Lag2         0
# Lag3         0
# Lag4         0
# Lag5         0
# Volume       0
# Today        0
# Direction    0
# dtype: int64

# %%
df.describe()
# Out:
#               Year         Lag1         Lag2         Lag3         Lag4  \
# count  1250.000000  1250.000000  1250.000000  1250.000000  1250.000000
# mean   2003.016000     0.003834     0.003919     0.001716     0.001636
# std       1.409018     1.136299     1.136280     1.138703     1.138774
# min    2001.000000    -4.922000    -4.922000    -4.922000    -4.922000
# 25%    2002.000000    -0.639500    -0.639500    -0.640000    -0.640000
# 50%    2003.000000     0.039000     0.039000     0.038500     0.038500
# 75%    2004.000000     0.596750     0.596750     0.596750     0.596750
# max    2005.000000     5.733000     5.733000     5.733000     5.733000
#
#              Lag5       Volume        Today
# count  1250.00000  1250.000000  1250.000000
# mean      0.00561     1.478305     0.003138
# std       1.14755     0.360357     1.136334
# min      -4.92200     0.356070    -4.922000
# 25%      -0.64000     1.257400    -0.639500
# 50%       0.03850     1.422950     0.038500
# ...

# %%
df['Direction'].value_counts()
# Out:
# Up      648
# Down    602
# Name: Direction, dtype: int64

# %%
df['average_Lag']=(df['Lag1']+df['Lag2']+df['Lag3']+df['Lag4']+df['Lag5'])/5

# %%
df.head()
# Out:
#    Year   Lag1   Lag2   Lag3   Lag4   Lag5  Volume  Today Direction  \
# 0  2001  0.381 -0.192 -2.624 -1.055  5.010  1.1913  0.959        Up
# 1  2001  0.959  0.381 -0.192 -2.624 -1.055  1.2965  1.032        Up
# 2  2001  1.032  0.959  0.381 -0.192 -2.624  1.4112 -0.623      Down
# 3  2001 -0.623  1.032  0.959  0.381 -0.192  1.2760  0.614        Up
# 4  2001  0.614 -0.623  1.032  0.959  0.381  1.2057  0.213        Up
#
#    average_Lag
# 0       0.3040
# 1      -0.5062
# 2      -0.0888
# 3       0.3114
# 4       0.4726

# %%
df.dtypes
# Out:
# Year             int64
# Lag1           float64
# Lag2           float64
# Lag3           float64
# Lag4           float64
# Lag5           float64
# Volume         float64
# Today          float64
# Direction       object
# average_Lag    float64
# dtype: object

# %%
df.head()
# Out:
#    Year   Lag1   Lag2   Lag3   Lag4   Lag5  Volume  Today Direction  \
# 0  2001  0.381 -0.192 -2.624 -1.055  5.010  1.1913  0.959        Up
# 1  2001  0.959  0.381 -0.192 -2.624 -1.055  1.2965  1.032        Up
# 2  2001  1.032  0.959  0.381 -0.192 -2.624  1.4112 -0.623      Down
# 3  2001 -0.623  1.032  0.959  0.381 -0.192  1.2760  0.614        Up
# 4  2001  0.614 -0.623  1.032  0.959  0.381  1.2057  0.213        Up
#
#    average_Lag
# 0       0.3040
# 1      -0.5062
# 2      -0.0888
# 3       0.3114
# 4       0.4726

# %%
df[df['average_Lag']==max(df['average_Lag'])]
# Out:
#      Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction  \
# 387  2002  0.425  5.408  1.688 -0.563  5.733  1.82609  0.979        Up
#
#      average_Lag
# 387       2.5382

# %%
df[df['average_Lag']==min(df['average_Lag'])]
# Out:
#      Year   Lag1   Lag2   Lag3  Lag4   Lag5  Volume  Today Direction  \
# 173  2001 -1.903 -3.106 -1.611 -0.58 -4.922  2.3173  3.898        Up
#
#      average_Lag
# 173      -2.4244

# %%
df[df['Volume']==max(df['Volume'])]
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction  \
# 1177  2005  0.829  0.046 -0.328 -0.754 -0.074  3.15247 -0.557      Down
#
#       average_Lag
# 1177      -0.0562

# %%
df[df['Volume']==min(df['Volume'])]
# Out:
#      Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction  \
# 743  2003  0.169 -0.181  0.282  0.393 -0.048  0.35607   1.24        Up
#
#      average_Lag
# 743        0.123

# %%
import os
import mysql.connector as conn
import csv

# %%
df.columns
# Out:
# Index(['Year', 'Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume', 'Today',
#        'Direction', 'average_Lag'],
#       dtype='object')

# %%
df.columns=[x.replace(' ','_') for x in df.columns]
df.columns
# Out:
# Index(['Year', 'Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume', 'Today',
#        'Direction', 'average_Lag'],
#       dtype='object')

# %%
df.dtypes.values
# Out:
# array([dtype('int64'), dtype('float64'), dtype('float64'),
#        dtype('float64'), dtype('float64'), dtype('float64'),
#        dtype('float64'), dtype('float64'), dtype('O'), dtype('float64')],
#       dtype=object)

# %%
replacement={
    'int64':'bigint(50)',
    'float64':'float(50)',
    'object':'varchar(100)'
}

# %%
df.dtypes.replace(replacement)
# Out:
# Year             bigint(50)
# Lag1              float(50)
# Lag2              float(50)
# Lag3              float(50)
# Lag4              float(50)
# Lag5              float(50)
# Volume            float(50)
# Today             float(50)
# Direction      varchar(100)
# average_Lag       float(50)
# dtype: object

# %%
columns = ", ".join("{} {}".format(a,b) for (a,b) in zip(df.columns, df.dtypes.replace(replacement)))
columns
# Out:
# 'Year bigint(50), Lag1 float(50), Lag2 float(50), Lag3 float(50), Lag4 float(50), Lag5 float(50), Volume float(50), Today float(50), Direction varchar(100), average_Lag float(50)'

# %%
connection=conn.connect(host='localhost',user='root',passwd='Luci1108$')
cursor=connection.cursor()
print("Successfully connected!!")
# Out:
# Successfully connected!!

# %%
cursor.execute('create database Smarket_data')

# %%
cursor.execute('use Smarket_data')

# %%
cursor.execute('create table Smarket ({})'.format(columns))

# %%
for i,row in df.iterrows():
    print('insert into Smarket values({},{},{},{},{},{},{},{},{},{})'.format(row[0],row[1],row[2],row[3],row[4],row[5],row[6],row[7],row[8],row[9]))
# Out:
# insert into Smarket values(2001,0.381,-0.192,-2.624,-1.055,5.01,1.1913,0.959,Up,0.30399999999999994)
# insert into Smarket values(2001,0.959,0.381,-0.192,-2.624,-1.055,1.2965,1.032,Up,-0.5062)
# insert into Smarket values(2001,1.032,0.959,0.381,-0.192,-2.624,1.4112,-0.623,Down,-0.08880000000000007)
# insert into Smarket values(2001,-0.623,1.032,0.959,0.381,-0.192,1.276,0.614,Up,0.3114)
# insert into Smarket values(2001,0.614,-0.623,1.032,0.959,0.381,1.2057,0.213,Up,0.4726000000000001)
# insert into Smarket values(2001,0.213,0.614,-0.623,1.032,0.959,1.3491,1.392,Up,0.43899999999999995)
# insert into Smarket values(2001,1.392,0.213,0.614,-0.623,1.032,1.445,-0.403,Down,0.5256000000000001)
# insert into Smarket values(2001,-0.403,1.392,0.213,0.614,-0.623,1.4078,0.027,Up,0.23859999999999998)
# insert into Smarket values(2001,0.027,-0.403,1.392,0.213,0.614,1.164,1.303,Up,0.3686)
# insert into Smarket values(2001,1.303,0.027,-0.403,1.392,0.213,1.2326,0.287,Up,0.5064)
# ...

# %%
df.head()
# Out:
#    Year   Lag1   Lag2   Lag3   Lag4   Lag5  Volume  Today Direction  \
# 0  2001  0.381 -0.192 -2.624 -1.055  5.010  1.1913  0.959        Up
# 1  2001  0.959  0.381 -0.192 -2.624 -1.055  1.2965  1.032        Up
# 2  2001  1.032  0.959  0.381 -0.192 -2.624  1.4112 -0.623      Down
# 3  2001 -0.623  1.032  0.959  0.381 -0.192  1.2760  0.614        Up
# 4  2001  0.614 -0.623  1.032  0.959  0.381  1.2057  0.213        Up
#
#    average_Lag
# 0       0.3040
# 1      -0.5062
# 2      -0.0888
# 3       0.3114
# 4       0.4726

# %%
len(df.columns)
# Out:
# 10

# %%
for i,row in df.iterrows():
            print(tuple(row))
            
            sql = "INSERT INTO Smarket VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql,list(row))
            print("Record inserted")
            
            connection.commit()
# Out:
# (2001, 0.381, -0.192, -2.624, -1.055, 5.01, 1.1913, 0.959, 'Up', 0.30399999999999994)
# Record inserted
# (2001, 0.959, 0.381, -0.192, -2.624, -1.055, 1.2965, 1.032, 'Up', -0.5062)
# Record inserted
# (2001, 1.032, 0.959, 0.381, -0.192, -2.624, 1.4112, -0.623, 'Down', -0.08880000000000007)
# Record inserted
# (2001, -0.623, 1.032, 0.959, 0.381, -0.192, 1.276, 0.614, 'Up', 0.3114)
# Record inserted
# (2001, 0.614, -0.623, 1.032, 0.959, 0.381, 1.2057, 0.213, 'Up', 0.4726000000000001)
# Record inserted
# (2001, 0.213, 0.614, -0.623, 1.032, 0.959, 1.3491, 1.392, 'Up', 0.43899999999999995)
# Record inserted
# (2001, 1.392, 0.213, 0.614, -0.623, 1.032, 1.445, -0.403, 'Down', 0.5256000000000001)
# Record inserted
# (2001, -0.403, 1.392, 0.213, 0.614, -0.623, 1.4078, 0.027, 'Up', 0.23859999999999998)
# Record inserted
# (2001, 0.027, -0.403, 1.392, 0.213, 0.614, 1.164, 1.303, 'Up', 0.3686)
# Record inserted
# (2001, 1.303, 0.027, -0.403, 1.392, 0.213, 1.2326, 0.287, 'Up', 0.5064)
# ...

# %%
df.shape
# Out:
# (1250, 10)

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv')

# %%
df1.head()
# Out:
#          date  values.I2P  values.P2I  values.JPI
# 0  1996-04-01   -2.580556   -0.836444        63.3
# 1  1996-05-01   -2.882258   -1.972581        66.3
# 2  1996-06-01   -1.742778   -0.478778        59.7
# 3  1996-07-01   -0.397796   -1.574301        63.3
# 4  1996-08-01   -0.977151   -1.797312        63.8

# %%
df1.dtypes
# Out:
# date           object
# values.I2P    float64
# values.P2I    float64
# values.JPI    float64
# dtype: object

# %%
replacement={
    'object':'varchar(100)',
    'float64':'float(50)'
}

# %%
df1.columns
# Out:
# Index(['date', 'values_I2P', 'values_P2I', 'values_JPI'], dtype='object')

# %%
len(df1.columns)
# Out:
# 4

# %%
df1.columns=[i.replace(".","_") for i in df1.columns]
df1.columns
# Out:
# Index(['date', 'values_I2P', 'values_P2I', 'values_JPI'], dtype='object')

# %%
columns = ", ".join("{} {}".format(a,b) for (a,b) in zip(df1.columns, df1.dtypes.replace(replacement)))
columns
# Out:
# 'date varchar(100), values_I2P float(50), values_P2I float(50), values_JPI float(50)'

# %%
cursor.execute('create table Bcf ({})'.format(columns))

# %%
for (i,row) in df1.iterrows():
    statement='insert into Bcf values({},{},{},{})'.format(row[0],row[1],row[2],row[3])
    cursor.execute(statement)
    print("Record inserted")
    connection.commit()
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
df1.shape
# Out:
# (117, 4)

# %%
cursor.execute('create table Bcf1 ({})'.format(columns))

# %%
for (i,row) in df1.iterrows():
    statement='insert into Bcf1 values(%s,%s,%s,%s)'
    cursor.execute(statement,list(row))
    print("Record inserted")
    connection.commit()
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/sudh9931/data/main/haberman.csv',header=None,names=['one','two','three','four'])

# %%
df2.head()
# Out:
#    one  two  three  four
# 0   30   64      1     1
# 1   30   62      3     1
# 2   30   65      0     1
# 3   31   59      2     1
# 4   31   65      4     1

# %%
df2.dtypes
# Out:
# one      int64
# two      int64
# three    int64
# four     int64
# dtype: object

# %%
replaced={
    'int64':'bigint(50)'
}

# %%
df2.columns
# Out:
# Index(['one', 'two', 'three', 'four'], dtype='object')

# %%
columns=",".join("{} {}".format(a,b) for (a,b) in zip(df2.columns,df2.dtypes.replace(replaced)))
columns
# Out:
# 'one bigint(50),two bigint(50),three bigint(50),four bigint(50)'

# %%
cursor.execute('create table haberman ({})'.format(columns))

# %%
for (i,row) in df2.iterrows():
    statement='insert into haberman values(%s,%s,%s,%s)'
    cursor.execute(statement,list(row))
    print('Record inserted')
    connection.commit()
print
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
df2.shape
# Out:
# (306, 4)

# %%
df3=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df3)
# Out:
# list

# %%
type(df3[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df3[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
len(df3)
# Out:
# 1

# %%
len(df3[0].columns)
# Out:
# 30

# %%
df3[0].dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG_       object
# 3P        object
# 3PA       object
# 3P_       object
# 2P        object
# 2PA       object
# 2P_       object
# eFG_      object
# FT        object
# FTA       object
# FT_       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3[0].isnull().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG_        2
# 3P         0
# 3PA        0
# 3P_       81
# 2P         0
# 2PA        0
# 2P_        4
# eFG_       2
# FT         0
# FTA        0
# FT_       25
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %%
df3[0].fillna('<na>',inplace=True)

# %%
df3[0].isnull().sum()
# Out:
# Rk        0
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG_       0
# 3P        0
# 3PA       0
# 3P_       0
# 2P        0
# 2PA       0
# 2P_       0
# eFG_      0
# FT        0
# FTA       0
# FT_       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# dtype: int64

# %%
df3[0].columns=[i.replace('%','_') for i in df3[0].columns]
df3[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG_',
#        '3P', '3PA', '3P_', '2P', '2PA', '2P_', 'eFG_', 'FT', 'FTA', 'FT_',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
replacement={
    'object':'varchar(100)'
    
}

# %%
columns=",".join("{} {}".format(a,b) for (a,b) in zip(df3[0].columns,df3[0].dtypes.replace(replacement)))
columns
# Out:
# 'Rk varchar(100),Player varchar(100),Pos varchar(100),Age varchar(100),Tm varchar(100),G varchar(100),GS varchar(100),MP varchar(100),FG varchar(100),FGA varchar(100),FG_ varchar(100),3P varchar(100),3PA varchar(100),3P_ varchar(100),2P varchar(100),2PA varchar(100),2P_ varchar(100),eFG_ varchar(100),FT varchar(100),FTA varchar(100),FT_ varchar(100),ORB varchar(100),DRB varchar(100),TRB varchar(100),AST varchar(100),STL varchar(100),BLK varchar(100),TOV varchar(100),PF varchar(100),PTS varchar(100)'

# %%
cursor.execute('create table basketball ({})'.format(columns))

# %%
for (i,row) in df3[0].iterrows():
    sql='insert into basketball values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'
    cursor.execute(sql,list(row))
    print("Record Iserted")
    connection.commit()
print("All rcords Inserted")
# Out:
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# Record Iserted
# ...

# %%
df3[0].shape
# Out:
# (675, 30)

# %%
data=pd.read_excel(r'C:\Users\ks\Desktop\Ineuron_pythonProject\24-07 Pandas day1\Dataset\data fsds\Attribute DataSet.xlsx')

# %%
data.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
data.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# waiseline          object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation      int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# waiseline          87
# Material          128
# FabricType        266
# Decoration        236
# Pattern Type      109
# Recommendation      0
# dtype: int64

# %%
data.describe()
# Out:
#            Dress_ID      Rating  Recommendation
# count  5.000000e+02  500.000000      500.000000
# mean   9.055417e+08    3.528600        0.420000
# std    1.736190e+08    2.005364        0.494053
# min    4.442820e+08    0.000000        0.000000
# 25%    7.673164e+08    3.700000        0.000000
# 50%    9.083296e+08    4.600000        0.000000
# 75%    1.039534e+09    4.800000        1.000000
# max    1.253973e+09    5.000000        1.000000

# %%
sample=data[data.dtypes[data.dtypes=='object'].index]

# %%
sample
# Out:
#        Style    Price  Size  Season   NeckLine SleeveLength waiseline  \
# 0       Sexy      Low     M  Summer     o-neck    sleevless    empire
# 1     Casual      Low     L  Summer     o-neck        Petal   natural
# 2    vintage     High     L  Automn     o-neck         full   natural
# 3      Brief  Average     L  Spring     o-neck         full   natural
# 4       cute      Low     M  Summer     o-neck    butterfly   natural
# ..       ...      ...   ...     ...        ...          ...       ...
# 495   Casual      Low     M  Spring     o-neck         full   natural
# 496     Sexy      Low  free  Summer     o-neck         full    empire
# 497   Casual  Average     M  Summer     v-neck         full    empire
# 498   Casual  Average     L  winter  boat-neck    sleevless    empire
# 499   Casual      Low  free  Summer     v-neck        short    empire
#
#           Material  FabricType  Decoration Pattern Type
# 0              NaN     chiffon     ruffles       animal
# ...

# %%
sample.describe()
# Out:
#          Style    Price Size  Season NeckLine SleeveLength waiseline Material  \
# count      500      498  500     498      497          498       413      372
# unique      13        7    7       8       16           17         4       23
# top     Casual  Average    M  Summer   o-neck    sleevless   natural   cotton
# freq       232      252  177     159      271          223       304      152
#
#        FabricType Decoration Pattern Type
# count         234        264          391
# unique         22         24           14
# top       chiffon       lace        solid
# freq          135         70          203

# %%
data.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# waiseline          87
# Material          128
# FabricType        266
# Decoration        236
# Pattern Type      109
# Recommendation      0
# dtype: int64

# %%
data[data['FabricType']=='chiffon']
# Out:
#        Dress_ID     Style    Price  Rating  Size  Season NeckLine  \
# 0    1006032852      Sexy      Low     4.6     M  Summer   o-neck
# 3     966005983     Brief  Average     4.6     L  Spring   o-neck
# 4     876339541      cute      Low     4.5     M  Summer   o-neck
# 9     985292672  bohemian      Low     0.0  free  Summer   v-neck
# 12    957723897      sexy      Low     4.7     M  Winter   o-neck
# ..          ...       ...      ...     ...   ...     ...      ...
# 488   511503677    Casual      Low     4.4     M  Summer   o-neck
# 490   641665398    Casual      Low     4.8  free  winter  bowneck
# 492   859922576      cute  Average     4.6     M  Spring   o-neck
# 493   817353671  bohemian      Low     4.6  free  Summer   o-neck
# 494   990559192     Brief  Average     4.7     M  winter   o-neck
#
#      SleeveLength waiseline       Material FabricType  Decoration  \
# 0       sleevless    empire            NaN    chiffon     ruffles
# ...

# %%
data['FabricType'].value_counts()
# Out:
# chiffon       135
# broadcloth     31
# worsted        19
# jersey         12
# shiffon         9
# sattin          6
# batik           2
# wollen          2
# Corduroy        2
# poplin          2
# dobby           2
# tulle           2
# organza         1
# knitted         1
# lace            1
# knitting        1
# flannel         1
# woolen          1
# flannael        1
# satin           1
# other           1
# terry           1
# Name: FabricType, dtype: int64

# %%
data.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# waiseline          87
# Material            0
# FabricType          0
# Decoration          0
# Pattern Type      109
# Recommendation      0
# dtype: int64

# %%
data['Material'].value_counts()
# Out:
# cotton           280
# polyster          99
# silk              26
# chiffonfabric     25
# mix               12
# nylon             10
# rayon             10
# milksilk           5
# spandex            5
# cashmere           4
# linen              3
# lycra              3
# microfiber         3
# acrylic            3
# viscos             2
# shiffon            2
# other              2
# modal              1
# knitting           1
# sill               1
# wool               1
# model              1
# lace               1
# Name: Material, dtype: int64

# %%
data['Decoration'].value_counts()
# Out:
# lace          70
# sashes        42
# beading       22
# hollowout     21
# applique      21
# ruffles       17
# bow           15
# sequined      14
# button         6
# pockets        5
# embroidary     5
# flowers        4
# ruched         3
# crystal        3
# rivet          3
# feathers       2
# draped         2
# plain          2
# none           2
# pearls         1
# pleat          1
# Tiered         1
# tassel         1
# cascading      1
# Name: Decoration, dtype: int64

# %%
data['Pattern Type'].value_counts()
# Out:
# solid        203
# print         71
# patchwork     48
# animal        21
# striped       17
# dot           14
# geometric      5
# plaid          3
# leopard        3
# floral         2
# character      1
# splice         1
# leapord        1
# none           1
# Name: Pattern Type, dtype: int64

# %%
data['FabricType'].fillna('chiffon',inplace=True)

# %%
data['Material'].fillna('cotton',inplace=True)

# %%
data['Decoration'].fillna('lace',inplace=True)

# %%
data['Pattern Type'].fillna('solid',inplace=True)

# %%
data.isnull().sum()
# Out:
# Dress_ID          0
# Style             0
# Price             2
# Rating            0
# Size              0
# Season            2
# NeckLine          3
# SleeveLength      2
# waiseline         0
# Material          0
# FabricType        0
# Decoration        0
# Pattern Type      0
# Recommendation    0
# dtype: int64

# %%
data['waiseline'].value_counts()
# Out:
# natural     391
# empire      104
# dropped       4
# princess      1
# Name: waiseline, dtype: int64

# %%
data.shape
# Out:
# (500, 14)

# %%
data['waiseline'].fillna('natural',inplace=True)

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (493, 14)

# %%
data.isnull().sum()
# Out:
# Dress_ID          0
# Style             0
# Price             0
# Rating            0
# Size              0
# Season            0
# NeckLine          0
# SleeveLength      0
# waiseline         0
# Material          0
# FabricType        0
# Decoration        0
# Pattern Type      0
# Recommendation    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation'],
#       dtype='object')

# %%
data.columns=[i.replace(" ","_") for i in data.columns]
data.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern_Type', 'Recommendation'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# waiseline          object
# Material           object
# FabricType         object
# Decoration         object
# Pattern_Type       object
# Recommendation      int64
# dtype: object

# %%
replacement={
    "int64":"int(50)",
    "float64":"float(50)",
    "object":"varchar(100)"
}

# %%
len(data.columns)
# Out:
# 14

# %%
columns=",".join("{} {}".format(a,b) for (a,b) in zip(data.columns,data.dtypes.replace(replacement)))
columns
# Out:
# 'Dress_ID int(50),Style varchar(100),Price varchar(100),Rating float(50),Size varchar(100),Season varchar(100),NeckLine varchar(100),SleeveLength varchar(100),waiseline varchar(100),Material varchar(100),FabricType varchar(100),Decoration varchar(100),Pattern_Type varchar(100),Recommendation int(50)'

# %%
cursor.execute('create table Attribute({})'.format(columns))

# %%
for (i,row) in data.iterrows():
    sql='insert into Attribute values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'
    cursor.execute(sql,list(row))
    print("Record inserted")
    connection.commit()
print("All records inserted successfully!!")
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
dress=pd.read_excel(r'C:\Users\ks\Desktop\Ineuron_pythonProject\24-07 Pandas day1\Dataset\data fsds\Dress Sales.xlsx')

# %%
dress.head()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0  1006032852       2114       2274                 2491                 2660
# 1  1212192089        151        275                  570                  750
# 2  1190380701          6          7                    7                    7
# 3   966005983       1005       1128                 1326                 1455
# 4   876339541        996       1175                 1304                 1396
#
#    2013-06-09 00:00:00  2013-08-09 00:00:00  2013-10-09 00:00:00  \
# 0                 2727                 2887                 2930
# 1                  813                 1066                 1164
# 2                    8                    8                    9
# 3                 1507                 1621                 1637
# 4                 1432                 1559                 1570
#
#   2013-12-09 00:00:00 14/9/2013  ... 24/9/2013 26/9/2013 28/9/2013 30/9/2013  \
# ...

# %%
dress.shape
# Out:
# (500, 24)

# %%
dress.dtypes
# Out:
# Dress_ID                 int64
# 29/8/2013                int64
# 31/8/2013                int64
# 2013-02-09 00:00:00      int64
# 2013-04-09 00:00:00      int64
# 2013-06-09 00:00:00      int64
# 2013-08-09 00:00:00      int64
# 2013-10-09 00:00:00      int64
# 2013-12-09 00:00:00     object
# 14/9/2013               object
# 16/9/2013               object
# 18/9/2013               object
# 20/9/2013               object
# 22/9/2013               object
# 24/9/2013                int64
# 26/9/2013              float64
# 28/9/2013                int64
# 30/9/2013              float64
# 2013-02-10 00:00:00    float64
# 2013-04-10 00:00:00    float64
# 2013-06-10 00:00:00      int64
# 2010-08-10 00:00:00    float64
# 2013-10-10 00:00:00    float64
# 2013-12-10 00:00:00      int64
# dtype: object

# %%
dress.isnull().sum()
# Out:
# Dress_ID                 0
# 29/8/2013                0
# 31/8/2013                0
# 2013-02-09 00:00:00      0
# 2013-04-09 00:00:00      0
# 2013-06-09 00:00:00      0
# 2013-08-09 00:00:00      0
# 2013-10-09 00:00:00      0
# 2013-12-09 00:00:00      0
# 14/9/2013                0
# 16/9/2013                0
# 18/9/2013                0
# 20/9/2013                0
# 22/9/2013                0
# 24/9/2013                0
# 26/9/2013              237
# 28/9/2013                0
# 30/9/2013              273
# 2013-02-10 00:00:00    275
# 2013-04-10 00:00:00    274
# 2013-06-10 00:00:00      0
# 2010-08-10 00:00:00    271
# 2013-10-10 00:00:00    271
# 2013-12-10 00:00:00      0
# dtype: int64

# %%
dress.describe()
# Out:
#            Dress_ID   29/8/2013    31/8/2013  2013-02-09 00:00:00  \
# count  5.000000e+02   500.00000   500.000000           500.000000
# mean   9.055417e+08   189.76600   200.966000           214.162000
# std    1.736190e+08   568.26459   579.802126           591.975613
# min    4.442820e+08     0.00000     0.000000             0.000000
# 25%    7.673164e+08     0.00000     0.000000             0.000000
# 50%    9.083296e+08     1.00000     1.000000             2.000000
# 75%    1.039534e+09   124.25000   145.250000           179.750000
# max    1.253973e+09  7455.00000  7467.000000          7479.000000
#
#        2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# count           500.000000           500.000000           500.000000
# mean            298.672000           303.658000           315.294000
# std             593.140026           595.178184           600.208193
# min               1.000000             1.000000             1.000000
# ...

# %%
dress.columns
# Out:
# Index([         'Dress_ID',         '29/8/2013',         '31/8/2013',
#        2013-02-09 00:00:00, 2013-04-09 00:00:00, 2013-06-09 00:00:00,
#        2013-08-09 00:00:00, 2013-10-09 00:00:00, 2013-12-09 00:00:00,
#                '14/9/2013',         '16/9/2013',         '18/9/2013',
#                '20/9/2013',         '22/9/2013',         '24/9/2013',
#                '26/9/2013',         '28/9/2013',         '30/9/2013',
#        2013-02-10 00:00:00, 2013-04-10 00:00:00, 2013-06-10 00:00:00,
#        2010-08-10 00:00:00, 2013-10-10 00:00:00, 2013-12-10 00:00:00],
#       dtype='object')

# %%
len(dress.columns)
# Out:
# 24

# %%
dress.isnull().sum()
# Out:
# Dress_ID                 0
# 29/8/2013                0
# 31/8/2013                0
# 2013-02-09 00:00:00      0
# 2013-04-09 00:00:00      0
# 2013-06-09 00:00:00      0
# 2013-08-09 00:00:00      0
# 2013-10-09 00:00:00      0
# 2013-12-09 00:00:00      0
# 14/9/2013                0
# 16/9/2013                0
# 18/9/2013                0
# 20/9/2013                0
# 22/9/2013                0
# 24/9/2013                0
# 26/9/2013              237
# 28/9/2013                0
# 30/9/2013              273
# 2013-02-10 00:00:00    275
# 2013-04-10 00:00:00    274
# 2013-06-10 00:00:00      0
# 2010-08-10 00:00:00    271
# 2013-10-10 00:00:00    271
# 2013-12-10 00:00:00      0
# dtype: int64

# %%
dress.columns = ['`'+str(str(x).split(' ')[0])+'`' for x in dress.columns]
dress.columns
# Out:
# Index(['`Dress_ID`', '`29/8/2013`', '`31/8/2013`', '`2013-02-09`',
#        '`2013-04-09`', '`2013-06-09`', '`2013-08-09`', '`2013-10-09`',
#        '`2013-12-09`', '`14/9/2013`', '`16/9/2013`', '`18/9/2013`',
#        '`20/9/2013`', '`22/9/2013`', '`24/9/2013`', '`26/9/2013`',
#        '`28/9/2013`', '`30/9/2013`', '`2013-02-10`', '`2013-04-10`',
#        '`2013-06-10`', '`2010-08-10`', '`2013-10-10`', '`2013-12-10`'],
#       dtype='object')

# %%
dress.dtypes
# Out:
# `Dress_ID`        int64
# `29/8/2013`       int64
# `31/8/2013`       int64
# `2013-02-09`      int64
# `2013-04-09`      int64
# `2013-06-09`      int64
# `2013-08-09`      int64
# `2013-10-09`      int64
# `2013-12-09`     object
# `14/9/2013`      object
# `16/9/2013`      object
# `18/9/2013`      object
# `20/9/2013`      object
# `22/9/2013`      object
# `24/9/2013`       int64
# `26/9/2013`     float64
# `28/9/2013`       int64
# `30/9/2013`     float64
# `2013-02-10`    float64
# `2013-04-10`    float64
# `2013-06-10`      int64
# `2010-08-10`    float64
# `2013-10-10`    float64
# `2013-12-10`      int64
# dtype: object

# %%
dress.fillna('<na>',inplace=True)

# %%
dress.isnull().sum()
# Out:
# `Dress_ID`      0
# `29/8/2013`     0
# `31/8/2013`     0
# `2013-02-09`    0
# `2013-04-09`    0
# `2013-06-09`    0
# `2013-08-09`    0
# `2013-10-09`    0
# `2013-12-09`    0
# `14/9/2013`     0
# `16/9/2013`     0
# `18/9/2013`     0
# `20/9/2013`     0
# `22/9/2013`     0
# `24/9/2013`     0
# `26/9/2013`     0
# `28/9/2013`     0
# `30/9/2013`     0
# `2013-02-10`    0
# `2013-04-10`    0
# `2013-06-10`    0
# `2010-08-10`    0
# `2013-10-10`    0
# `2013-12-10`    0
# dtype: int64

# %%
replacement
# Out:
# {'int64': 'int(50)', 'float64': 'float(50)', 'object': 'varchar(100)'}

# %%
len(dress.columns)
# Out:
# 24

# %%
columns=",".join('{} {}'.format(a,b) for (a,b) in zip(dress.columns,dress.dtypes.replace(replacement)))
columns
# Out:
# '`Dress_ID` int(50),`29/8/2013` int(50),`31/8/2013` int(50),`2013-02-09` int(50),`2013-04-09` int(50),`2013-06-09` int(50),`2013-08-09` int(50),`2013-10-09` int(50),`2013-12-09` varchar(100),`14/9/2013` varchar(100),`16/9/2013` varchar(100),`18/9/2013` varchar(100),`20/9/2013` varchar(100),`22/9/2013` varchar(100),`24/9/2013` int(50),`26/9/2013` varchar(100),`28/9/2013` int(50),`30/9/2013` varchar(100),`2013-02-10` varchar(100),`2013-04-10` varchar(100),`2013-06-10` int(50),`2010-08-10` varchar(100),`2013-10-10` varchar(100),`2013-12-10` int(50)'

# %%
cursor.execute('create table dress({})'.format(columns))

# %%
for (i,row) in dress.iterrows():
    sql='insert into dress values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'
    cursor.execute(sql,list(row))
    print('Record Inserted')
    connection.commit()
print("All records inserted successfully!!!")
# Out:
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# Record Inserted
# ...

# %%
dress.shape
# Out:
# (500, 24)

# %%
data.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern_Type  Recommendation
# 0    empire         cotton    chiffon     ruffles       animal               1
# 1   natural     microfiber    chiffon     ruffles       animal               0
# 2   natural       polyster    chiffon        lace        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
data.to_json('Attributejson.json')

# %%
temp=pd.read_json('Attributejson.json')

# %%
temp.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern_Type  Recommendation
# 0    empire         cotton    chiffon     ruffles       animal               1
# 1   natural     microfiber    chiffon     ruffles       animal               0
# 2   natural       polyster    chiffon        lace        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
import pymongo

# %%
client = pymongo.MongoClient(
    "mongodb+srv://prasathkkps:Luci1108@cluster0.ldqcx.mongodb.net/?retryWrites=true&w=majority")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.ldqcx.mongodb.net:27017', 'cluster0-shard-00-01.ldqcx.mongodb.net:27017', 'cluster0-shard-00-02.ldqcx.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-2mebps-shard-0', tls=True), 'test')

# %%
database=client['AttributeData']
collection=database['Attribute']

# %%
data.reset_index(inplace=True)
data_dict = df.to_dict("records")
collection.insert_many(data_dict)

# %% [markdown]
# ## SQL COMMANDS

# %%
show databases;
use smarket_data;
show tables;
desc smarket;
select * from bcf1;
select count(*) from bcf1;
select * from smarket;
select count(*) from smarket;
select * from haberman;
select count(*) from haberman;
select * from basketball;
select count(*) from basketball;
select * from attribute;
select count(*) from attribute;
select * from dress;
select count(*) from dress;
desc dress;
desc attribute;
select * from dress;
select * from attribute;
select attribute.Dress_ID,Price,Rating,Size,Recommendation,'29/8/2013','31/8/2013' from attribute left join dress on attribute.Dress_ID=dress.Dress_ID;

select distinct count(Dress_ID) from dress;
select count(*) from attribute where recommendation=0;
